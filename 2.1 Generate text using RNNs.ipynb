# %%
from gutenberg.acquire import load_etext
from gutenberg.acquire.text import UnknownDownloadUriException
from gutenberg.cleanup import strip_headers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-540f0d65fee9> in <module>()
# ----> 1 from gutenberg.acquire import load_etext
#       2 from gutenberg.acquire.text import UnknownDownloadUriException
#       3 from gutenberg.cleanup import strip_headers
#
# ImportError: No module named 'gutenberg'
