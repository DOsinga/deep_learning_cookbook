# %%
import numpy as np
from keras.layers import Input, Dense, Lambda
from keras.layers.merge import concatenate as concat
from keras.models import Model
from keras import backend as K
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam

from io import BytesIO
import PIL
from IPython.display import clear_output, Image, display, HTML

# %%
def prepare(images, labels):
    images = images.astype('float32') / 255
    n, w, h = images.shape
    return images.reshape((n, w * h)), to_categorical(labels)

train, test = mnist.load_data()
x_train, y_train = prepare(*train)
x_test, y_test = prepare(*test)
img_width, img_height = train[0].shape[1:]

# %%
batch_size = 250
latent_space_depth = 2

def sample_z(args):
    z_mean, z_log_var = args
    eps = K.random_normal(shape=(batch_size, latent_space_depth), mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var / 2) * eps

# %%
def VariationalAutoEncoder(num_pixels):
    pixels = Input(shape=(num_pixels,))
    encoder_hidden = Dense(512, activation='relu')(pixels)

    z_mean = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    z_log_var = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    
    def KL_loss(y_true, y_pred):
        return(0.5 * K.sum(K.exp(z_log_var) + K.square(z_mean) - 1 - z_log_var, axis=1))

    def reconstruction_loss(y_true, y_pred):
        return K.sum(K.binary_crossentropy(y_true, y_pred), axis=-1)    

    def total_loss(y_true, y_pred):
        return KL_loss(y_true, y_pred) + reconstruction_loss(y_true, y_pred)

    z = Lambda(sample_z, output_shape=(latent_space_depth, ))([z_mean, z_log_var])
    
    decoder_hidden = Dense(512, activation='relu')

    reconstruct_pixels = Dense(num_pixels, activation='sigmoid')

    decoder_in = Input(shape=(latent_space_depth,))
    hidden = decoder_hidden(decoder_in)
    decoder_out = reconstruct_pixels(hidden)
    decoder = Model(decoder_in, decoder_out)    
    
    hidden = decoder_hidden(z)
    outputs = reconstruct_pixels(hidden)
    auto_encoder = Model(pixels, outputs)

    auto_encoder.compile(optimizer=Adam(lr=0.001), 
                         loss=total_loss,
                         metrics=[KL_loss, reconstruction_loss])
    
    return auto_encoder, decoder

auto_encoder, decoder = VariationalAutoEncoder(x_train.shape[1])
auto_encoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           (None, 784)          0
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 512)          401920      input_17[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 2)            1026        dense_32[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 2)            1026        dense_32[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 2)            0           dense_33[0][0]
#                                                                  dense_34[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 512)          1536        lambda_8[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 784)          402192      dense_35[1][0]
# ==================================================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 784), (60000, 10), (10000, 784), (10000, 10))

# %%
auto_encoder.fit(x_train, x_train, verbose=1, 
                 batch_size=batch_size, epochs=100,
                 validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 7s 125us/step - loss: 214.1281 - KL_loss: 10.7052 - reconstruction_loss: 203.4229 - val_loss: 181.8244 - val_KL_loss: 5.3993 - val_reconstruction_loss: 176.4251
# Epoch 2/100
# 60000/60000 [==============================] - 6s 101us/step - loss: 176.0493 - KL_loss: 4.8653 - reconstruction_loss: 171.1839 - val_loss: 170.5538 - val_KL_loss: 4.8051 - val_reconstruction_loss: 165.7487
# Epoch 3/100
# 60000/60000 [==============================] - 7s 109us/step - loss: 168.2982 - KL_loss: 4.8428 - reconstruction_loss: 163.4554 - val_loss: 166.6530 - val_KL_loss: 4.8240 - val_reconstruction_loss: 161.8290
# Epoch 4/100
# 60000/60000 [==============================] - 6s 106us/step - loss: 165.5347 - KL_loss: 4.9653 - reconstruction_loss: 160.5694 - val_loss: 164.8385 - val_KL_loss: 4.9888 - val_reconstruction_loss: 159.8497
# Epoch 5/100
# 60000/60000 [==============================] - 7s 114us/step - loss: 163.7700 - KL_loss: 5.0797 - reconstruction_loss: 158.6903 - val_loss: 163.0991 - val_KL_loss: 5.0738 - val_reconstruction_loss: 158.0253
# Epoch 6/100
# 60000/60000 [==============================] - 8s 131us/step - loss: 162.2533 - KL_loss: 5.1901 - reconstruction_loss: 157.0632 - val_loss: 161.8445 - val_KL_loss: 5.2710 - val_reconstruction_loss: 156.5735
# Epoch 7/100
# 60000/60000 [==============================] - 8s 128us/step - loss: 160.9642 - KL_loss: 5.2981 - reconstruction_loss: 155.6660 - val_loss: 160.6033 - val_KL_loss: 5.4190 - val_reconstruction_loss: 155.1843
# Epoch 8/100
# 60000/60000 [==============================] - 7s 122us/step - loss: 159.8441 - KL_loss: 5.3988 - reconstruction_loss: 154.4453 - val_loss: 159.6930 - val_KL_loss: 5.5321 - val_reconstruction_loss: 154.1609
# Epoch 9/100
# 60000/60000 [==============================] - 7s 122us/step - loss: 158.8782 - KL_loss: 5.4757 - reconstruction_loss: 153.4025 - val_loss: 158.7872 - val_KL_loss: 5.6106 - val_reconstruction_loss: 153.1766
# Epoch 10/100
# 60000/60000 [==============================] - 7s 124us/step - loss: 158.0099 - KL_loss: 5.5404 - reconstruction_loss: 152.4695 - val_loss: 158.1441 - val_KL_loss: 5.5470 - val_reconstruction_loss: 152.5971
# Epoch 11/100
# 60000/60000 [==============================] - 8s 127us/step - loss: 157.2516 - KL_loss: 5.6011 - reconstruction_loss: 151.6505 - val_loss: 157.5096 - val_KL_loss: 5.6985 - val_reconstruction_loss: 151.8111
# Epoch 12/100
# 60000/60000 [==============================] - 8s 137us/step - loss: 156.5844 - KL_loss: 5.6358 - reconstruction_loss: 150.9486 - val_loss: 156.8968 - val_KL_loss: 5.7259 - val_reconstruction_loss: 151.1709
# Epoch 13/100
# 60000/60000 [==============================] - 10s 158us/step - loss: 155.9854 - KL_loss: 5.6965 - reconstruction_loss: 150.2889 - val_loss: 156.3681 - val_KL_loss: 5.6687 - val_reconstruction_loss: 150.6994
# Epoch 14/100
# 60000/60000 [==============================] - 9s 143us/step - loss: 155.3902 - KL_loss: 5.7333 - reconstruction_loss: 149.6570 - val_loss: 156.1155 - val_KL_loss: 5.7443 - val_reconstruction_loss: 150.3712
# Epoch 15/100
# 60000/60000 [==============================] - 8s 136us/step - loss: 154.8850 - KL_loss: 5.7563 - reconstruction_loss: 149.1288 - val_loss: 155.6243 - val_KL_loss: 5.8168 - val_reconstruction_loss: 149.8075
# Epoch 16/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 154.4619 - KL_loss: 5.7957 - reconstruction_loss: 148.6662 - val_loss: 155.1267 - val_KL_loss: 5.7830 - val_reconstruction_loss: 149.3437
# Epoch 17/100
# 60000/60000 [==============================] - 9s 151us/step - loss: 153.9827 - KL_loss: 5.8103 - reconstruction_loss: 148.1724 - val_loss: 154.8084 - val_KL_loss: 5.8179 - val_reconstruction_loss: 148.9904
# Epoch 18/100
# 60000/60000 [==============================] - 9s 144us/step - loss: 153.5974 - KL_loss: 5.8243 - reconstruction_loss: 147.7730 - val_loss: 154.6081 - val_KL_loss: 5.8155 - val_reconstruction_loss: 148.7927
# Epoch 19/100
# 60000/60000 [==============================] - 8s 138us/step - loss: 153.2694 - KL_loss: 5.8501 - reconstruction_loss: 147.4193 - val_loss: 154.3049 - val_KL_loss: 5.9876 - val_reconstruction_loss: 148.3173
# Epoch 20/100
# 60000/60000 [==============================] - 10s 168us/step - loss: 152.9287 - KL_loss: 5.8673 - reconstruction_loss: 147.0614 - val_loss: 154.1877 - val_KL_loss: 5.8098 - val_reconstruction_loss: 148.3779
# Epoch 21/100
# 60000/60000 [==============================] - 10s 171us/step - loss: 152.6310 - KL_loss: 5.8868 - reconstruction_loss: 146.7443 - val_loss: 153.7143 - val_KL_loss: 5.9013 - val_reconstruction_loss: 147.8129
# Epoch 22/100
# 60000/60000 [==============================] - 8s 138us/step - loss: 152.3065 - KL_loss: 5.9001 - reconstruction_loss: 146.4064 - val_loss: 153.5815 - val_KL_loss: 5.7725 - val_reconstruction_loss: 147.8090
# Epoch 23/100
# 60000/60000 [==============================] - 9s 143us/step - loss: 152.0398 - KL_loss: 5.9063 - reconstruction_loss: 146.1335 - val_loss: 153.5477 - val_KL_loss: 5.9820 - val_reconstruction_loss: 147.5656
# Epoch 24/100
# 60000/60000 [==============================] - 9s 150us/step - loss: 151.7811 - KL_loss: 5.9320 - reconstruction_loss: 145.8491 - val_loss: 153.4320 - val_KL_loss: 5.8206 - val_reconstruction_loss: 147.6113
# Epoch 25/100
# 60000/60000 [==============================] - 9s 147us/step - loss: 151.5322 - KL_loss: 5.9397 - reconstruction_loss: 145.5926 - val_loss: 153.1780 - val_KL_loss: 5.9838 - val_reconstruction_loss: 147.1942
# Epoch 26/100
# 60000/60000 [==============================] - 9s 152us/step - loss: 151.3158 - KL_loss: 5.9545 - reconstruction_loss: 145.3612 - val_loss: 153.0342 - val_KL_loss: 5.9378 - val_reconstruction_loss: 147.0963
# Epoch 27/100
# 60000/60000 [==============================] - 9s 145us/step - loss: 151.0805 - KL_loss: 5.9680 - reconstruction_loss: 145.1125 - val_loss: 152.8495 - val_KL_loss: 5.9262 - val_reconstruction_loss: 146.9233
# Epoch 28/100
# 60000/60000 [==============================] - 8s 138us/step - loss: 150.8912 - KL_loss: 5.9827 - reconstruction_loss: 144.9086 - val_loss: 152.7259 - val_KL_loss: 5.9263 - val_reconstruction_loss: 146.7997
# Epoch 29/100
# 60000/60000 [==============================] - 9s 145us/step - loss: 150.6710 - KL_loss: 5.9967 - reconstruction_loss: 144.6743 - val_loss: 152.5021 - val_KL_loss: 5.9333 - val_reconstruction_loss: 146.5687
# Epoch 30/100
# 60000/60000 [==============================] - 9s 153us/step - loss: 150.4795 - KL_loss: 6.0001 - reconstruction_loss: 144.4794 - val_loss: 152.5714 - val_KL_loss: 5.9258 - val_reconstruction_loss: 146.6456
# Epoch 31/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 150.2969 - KL_loss: 6.0087 - reconstruction_loss: 144.2881 - val_loss: 152.3901 - val_KL_loss: 5.9065 - val_reconstruction_loss: 146.4836
# Epoch 32/100
# 60000/60000 [==============================] - 10s 160us/step - loss: 150.1377 - KL_loss: 6.0186 - reconstruction_loss: 144.1191 - val_loss: 152.2293 - val_KL_loss: 5.9372 - val_reconstruction_loss: 146.2921
# Epoch 33/100
# 60000/60000 [==============================] - 9s 153us/step - loss: 149.9040 - KL_loss: 6.0331 - reconstruction_loss: 143.8709 - val_loss: 152.0998 - val_KL_loss: 6.0264 - val_reconstruction_loss: 146.0734
# Epoch 34/100
# 60000/60000 [==============================] - 9s 151us/step - loss: 149.8222 - KL_loss: 6.0427 - reconstruction_loss: 143.7795 - val_loss: 152.2233 - val_KL_loss: 6.2152 - val_reconstruction_loss: 146.0081
# Epoch 35/100
# 60000/60000 [==============================] - 8s 137us/step - loss: 149.6705 - KL_loss: 6.0659 - reconstruction_loss: 143.6046 - val_loss: 152.2301 - val_KL_loss: 6.0097 - val_reconstruction_loss: 146.2204
# Epoch 36/100
# 60000/60000 [==============================] - 8s 128us/step - loss: 149.4652 - KL_loss: 6.0585 - reconstruction_loss: 143.4067 - val_loss: 151.9259 - val_KL_loss: 6.0785 - val_reconstruction_loss: 145.8475
# Epoch 37/100
# 60000/60000 [==============================] - 7s 124us/step - loss: 149.2914 - KL_loss: 6.0748 - reconstruction_loss: 143.2166 - val_loss: 151.7779 - val_KL_loss: 6.0048 - val_reconstruction_loss: 145.7731
# Epoch 38/100
# 60000/60000 [==============================] - 8s 129us/step - loss: 149.1922 - KL_loss: 6.0761 - reconstruction_loss: 143.1161 - val_loss: 152.0566 - val_KL_loss: 6.2925 - val_reconstruction_loss: 145.7641
# Epoch 39/100
# 60000/60000 [==============================] - 8s 128us/step - loss: 149.0389 - KL_loss: 6.0863 - reconstruction_loss: 142.9527 - val_loss: 151.9103 - val_KL_loss: 5.9954 - val_reconstruction_loss: 145.9149
# Epoch 40/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 148.9012 - KL_loss: 6.0979 - reconstruction_loss: 142.8032 - val_loss: 151.8481 - val_KL_loss: 5.9871 - val_reconstruction_loss: 145.8609
# Epoch 41/100
# 60000/60000 [==============================] - 11s 180us/step - loss: 148.7529 - KL_loss: 6.0963 - reconstruction_loss: 142.6566 - val_loss: 151.6686 - val_KL_loss: 6.1352 - val_reconstruction_loss: 145.5333
# Epoch 42/100
# 60000/60000 [==============================] - 9s 154us/step - loss: 148.6706 - KL_loss: 6.1164 - reconstruction_loss: 142.5543 - val_loss: 151.7423 - val_KL_loss: 6.0439 - val_reconstruction_loss: 145.6984
# Epoch 43/100
# 60000/60000 [==============================] - 8s 138us/step - loss: 148.5339 - KL_loss: 6.1186 - reconstruction_loss: 142.4153 - val_loss: 151.3352 - val_KL_loss: 6.0629 - val_reconstruction_loss: 145.2722
# Epoch 44/100
# 60000/60000 [==============================] - 8s 136us/step - loss: 148.3679 - KL_loss: 6.1205 - reconstruction_loss: 142.2474 - val_loss: 151.4178 - val_KL_loss: 6.0571 - val_reconstruction_loss: 145.3607
# Epoch 45/100
# 60000/60000 [==============================] - 8s 133us/step - loss: 148.3103 - KL_loss: 6.1273 - reconstruction_loss: 142.1830 - val_loss: 151.3546 - val_KL_loss: 6.1504 - val_reconstruction_loss: 145.2043
# Epoch 46/100
# 60000/60000 [==============================] - 8s 131us/step - loss: 148.1483 - KL_loss: 6.1318 - reconstruction_loss: 142.0165 - val_loss: 151.2847 - val_KL_loss: 6.0230 - val_reconstruction_loss: 145.2617
# Epoch 47/100
# 60000/60000 [==============================] - 8s 141us/step - loss: 148.0540 - KL_loss: 6.1380 - reconstruction_loss: 141.9160 - val_loss: 151.3765 - val_KL_loss: 6.0414 - val_reconstruction_loss: 145.3351
# Epoch 48/100
# 60000/60000 [==============================] - 8s 139us/step - loss: 147.9247 - KL_loss: 6.1557 - reconstruction_loss: 141.7689 - val_loss: 151.2288 - val_KL_loss: 6.1175 - val_reconstruction_loss: 145.1113
# Epoch 49/100
# 60000/60000 [==============================] - 9s 147us/step - loss: 147.8347 - KL_loss: 6.1565 - reconstruction_loss: 141.6782 - val_loss: 151.3949 - val_KL_loss: 6.1055 - val_reconstruction_loss: 145.2894
# Epoch 50/100
# 60000/60000 [==============================] - 9s 150us/step - loss: 147.7358 - KL_loss: 6.1759 - reconstruction_loss: 141.5599 - val_loss: 151.1783 - val_KL_loss: 6.1920 - val_reconstruction_loss: 144.9863
# Epoch 51/100
# 60000/60000 [==============================] - 9s 142us/step - loss: 147.6607 - KL_loss: 6.1708 - reconstruction_loss: 141.4899 - val_loss: 151.5140 - val_KL_loss: 6.2012 - val_reconstruction_loss: 145.3128
# Epoch 52/100
# 60000/60000 [==============================] - 8s 136us/step - loss: 147.5701 - KL_loss: 6.1877 - reconstruction_loss: 141.3824 - val_loss: 151.1871 - val_KL_loss: 6.1699 - val_reconstruction_loss: 145.0172
# Epoch 53/100
# 60000/60000 [==============================] - 8s 135us/step - loss: 147.4660 - KL_loss: 6.1894 - reconstruction_loss: 141.2766 - val_loss: 151.0802 - val_KL_loss: 6.1510 - val_reconstruction_loss: 144.9291
# Epoch 54/100
# 60000/60000 [==============================] - 9s 153us/step - loss: 147.3568 - KL_loss: 6.1783 - reconstruction_loss: 141.1785 - val_loss: 150.9429 - val_KL_loss: 6.0097 - val_reconstruction_loss: 144.9331
# Epoch 55/100
# 60000/60000 [==============================] - 9s 152us/step - loss: 147.2651 - KL_loss: 6.1942 - reconstruction_loss: 141.0708 - val_loss: 150.9385 - val_KL_loss: 6.0831 - val_reconstruction_loss: 144.8555
# Epoch 56/100
# 60000/60000 [==============================] - 10s 163us/step - loss: 147.1715 - KL_loss: 6.1994 - reconstruction_loss: 140.9722 - val_loss: 150.9214 - val_KL_loss: 6.0060 - val_reconstruction_loss: 144.9155
# Epoch 57/100
# 60000/60000 [==============================] - 9s 144us/step - loss: 147.1210 - KL_loss: 6.2103 - reconstruction_loss: 140.9107 - val_loss: 151.0507 - val_KL_loss: 6.1011 - val_reconstruction_loss: 144.9496
# Epoch 58/100
# 60000/60000 [==============================] - 9s 145us/step - loss: 146.9795 - KL_loss: 6.2118 - reconstruction_loss: 140.7677 - val_loss: 150.9784 - val_KL_loss: 6.1654 - val_reconstruction_loss: 144.8130
# Epoch 59/100
# 60000/60000 [==============================] - 9s 142us/step - loss: 146.9154 - KL_loss: 6.2062 - reconstruction_loss: 140.7092 - val_loss: 151.1834 - val_KL_loss: 6.0619 - val_reconstruction_loss: 145.1214
# Epoch 60/100
# 60000/60000 [==============================] - 9s 142us/step - loss: 146.8608 - KL_loss: 6.2258 - reconstruction_loss: 140.6351 - val_loss: 151.0328 - val_KL_loss: 6.2836 - val_reconstruction_loss: 144.7491
# Epoch 61/100
# 60000/60000 [==============================] - 8s 127us/step - loss: 146.7216 - KL_loss: 6.2231 - reconstruction_loss: 140.4984 - val_loss: 150.7960 - val_KL_loss: 6.1415 - val_reconstruction_loss: 144.6545
# Epoch 62/100
# 60000/60000 [==============================] - 8s 129us/step - loss: 146.6610 - KL_loss: 6.2241 - reconstruction_loss: 140.4370 - val_loss: 150.5898 - val_KL_loss: 6.2175 - val_reconstruction_loss: 144.3723
# Epoch 63/100
# 60000/60000 [==============================] - 8s 129us/step - loss: 146.6313 - KL_loss: 6.2409 - reconstruction_loss: 140.3904 - val_loss: 151.0693 - val_KL_loss: 6.1708 - val_reconstruction_loss: 144.8985
# Epoch 64/100
# 60000/60000 [==============================] - 9s 142us/step - loss: 146.4860 - KL_loss: 6.2370 - reconstruction_loss: 140.2490 - val_loss: 151.1347 - val_KL_loss: 6.1881 - val_reconstruction_loss: 144.9466
# Epoch 65/100
# 60000/60000 [==============================] - 8s 135us/step - loss: 146.4675 - KL_loss: 6.2492 - reconstruction_loss: 140.2183 - val_loss: 150.8752 - val_KL_loss: 6.1776 - val_reconstruction_loss: 144.6976
# Epoch 66/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 146.3822 - KL_loss: 6.2492 - reconstruction_loss: 140.1330 - val_loss: 150.8504 - val_KL_loss: 6.3286 - val_reconstruction_loss: 144.5217
# Epoch 67/100
# 60000/60000 [==============================] - 9s 143us/step - loss: 146.2880 - KL_loss: 6.2464 - reconstruction_loss: 140.0416 - val_loss: 150.7258 - val_KL_loss: 6.1723 - val_reconstruction_loss: 144.5535
# Epoch 68/100
# 60000/60000 [==============================] - 12s 195us/step - loss: 146.2449 - KL_loss: 6.2569 - reconstruction_loss: 139.9880 - val_loss: 150.8034 - val_KL_loss: 6.1547 - val_reconstruction_loss: 144.6488
# Epoch 69/100
# 60000/60000 [==============================] - 11s 188us/step - loss: 146.1123 - KL_loss: 6.2474 - reconstruction_loss: 139.8648 - val_loss: 150.6109 - val_KL_loss: 6.0606 - val_reconstruction_loss: 144.5503
# Epoch 70/100
# 60000/60000 [==============================] - 10s 174us/step - loss: 146.0751 - KL_loss: 6.2634 - reconstruction_loss: 139.8117 - val_loss: 150.6660 - val_KL_loss: 6.2311 - val_reconstruction_loss: 144.4349
# Epoch 71/100
# 60000/60000 [==============================] - 11s 186us/step - loss: 146.0239 - KL_loss: 6.2580 - reconstruction_loss: 139.7659 - val_loss: 150.6992 - val_KL_loss: 6.2205 - val_reconstruction_loss: 144.4787
# Epoch 72/100
# 60000/60000 [==============================] - 11s 187us/step - loss: 145.9766 - KL_loss: 6.2773 - reconstruction_loss: 139.6993 - val_loss: 150.6919 - val_KL_loss: 6.2597 - val_reconstruction_loss: 144.4322
# Epoch 73/100
# 60000/60000 [==============================] - 10s 171us/step - loss: 145.8744 - KL_loss: 6.2862 - reconstruction_loss: 139.5882 - val_loss: 150.5288 - val_KL_loss: 6.2426 - val_reconstruction_loss: 144.2862
# Epoch 74/100
# 60000/60000 [==============================] - 10s 168us/step - loss: 145.8255 - KL_loss: 6.2812 - reconstruction_loss: 139.5443 - val_loss: 150.5564 - val_KL_loss: 6.3397 - val_reconstruction_loss: 144.2167
# Epoch 75/100
# 60000/60000 [==============================] - 12s 195us/step - loss: 145.7868 - KL_loss: 6.2901 - reconstruction_loss: 139.4967 - val_loss: 150.6070 - val_KL_loss: 6.1866 - val_reconstruction_loss: 144.4204
# Epoch 76/100
# 60000/60000 [==============================] - 12s 205us/step - loss: 145.6879 - KL_loss: 6.2903 - reconstruction_loss: 139.3977 - val_loss: 150.4220 - val_KL_loss: 6.4185 - val_reconstruction_loss: 144.0035
# Epoch 77/100
# 60000/60000 [==============================] - 11s 175us/step - loss: 145.6541 - KL_loss: 6.3077 - reconstruction_loss: 139.3464 - val_loss: 150.5776 - val_KL_loss: 6.2359 - val_reconstruction_loss: 144.3417
# Epoch 78/100
# 60000/60000 [==============================] - 13s 221us/step - loss: 145.5701 - KL_loss: 6.3044 - reconstruction_loss: 139.2657 - val_loss: 150.5575 - val_KL_loss: 6.2673 - val_reconstruction_loss: 144.2902
# Epoch 79/100
# 60000/60000 [==============================] - 15s 244us/step - loss: 145.5087 - KL_loss: 6.2954 - reconstruction_loss: 139.2133 - val_loss: 150.5740 - val_KL_loss: 6.4186 - val_reconstruction_loss: 144.1554
# Epoch 80/100
# 60000/60000 [==============================] - 11s 191us/step - loss: 145.4768 - KL_loss: 6.2939 - reconstruction_loss: 139.1829 - val_loss: 150.6282 - val_KL_loss: 6.3287 - val_reconstruction_loss: 144.2995
# Epoch 81/100
# 60000/60000 [==============================] - 10s 170us/step - loss: 145.4040 - KL_loss: 6.3106 - reconstruction_loss: 139.0934 - val_loss: 150.4470 - val_KL_loss: 6.2072 - val_reconstruction_loss: 144.2398
# Epoch 82/100
# 60000/60000 [==============================] - 14s 232us/step - loss: 145.3509 - KL_loss: 6.3037 - reconstruction_loss: 139.0472 - val_loss: 150.4364 - val_KL_loss: 6.2644 - val_reconstruction_loss: 144.1720
# Epoch 83/100
# 60000/60000 [==============================] - 12s 208us/step - loss: 145.2625 - KL_loss: 6.3128 - reconstruction_loss: 138.9497 - val_loss: 150.6532 - val_KL_loss: 6.2198 - val_reconstruction_loss: 144.4334
# Epoch 84/100
# 60000/60000 [==============================] - 12s 199us/step - loss: 145.2665 - KL_loss: 6.3269 - reconstruction_loss: 138.9396 - val_loss: 150.5046 - val_KL_loss: 6.2913 - val_reconstruction_loss: 144.2133
# Epoch 85/100
# 60000/60000 [==============================] - 13s 223us/step - loss: 145.1802 - KL_loss: 6.3199 - reconstruction_loss: 138.8603 - val_loss: 150.3556 - val_KL_loss: 6.3002 - val_reconstruction_loss: 144.0553
# Epoch 86/100
# 60000/60000 [==============================] - 14s 229us/step - loss: 145.1094 - KL_loss: 6.3310 - reconstruction_loss: 138.7783 - val_loss: 150.3403 - val_KL_loss: 6.2316 - val_reconstruction_loss: 144.1087
# Epoch 87/100
# 60000/60000 [==============================] - 12s 203us/step - loss: 145.1000 - KL_loss: 6.3285 - reconstruction_loss: 138.7715 - val_loss: 150.4393 - val_KL_loss: 6.1519 - val_reconstruction_loss: 144.2874
# Epoch 88/100
# 60000/60000 [==============================] - 12s 192us/step - loss: 145.0442 - KL_loss: 6.3374 - reconstruction_loss: 138.7067 - val_loss: 150.4658 - val_KL_loss: 6.2267 - val_reconstruction_loss: 144.2391
# Epoch 89/100
# 60000/60000 [==============================] - 13s 212us/step - loss: 144.9752 - KL_loss: 6.3343 - reconstruction_loss: 138.6409 - val_loss: 150.4935 - val_KL_loss: 6.2891 - val_reconstruction_loss: 144.2044
# Epoch 90/100
# 60000/60000 [==============================] - 11s 178us/step - loss: 144.8846 - KL_loss: 6.3547 - reconstruction_loss: 138.5299 - val_loss: 150.5267 - val_KL_loss: 6.4122 - val_reconstruction_loss: 144.1145
# Epoch 91/100
# 60000/60000 [==============================] - 10s 166us/step - loss: 144.8968 - KL_loss: 6.3544 - reconstruction_loss: 138.5424 - val_loss: 150.6177 - val_KL_loss: 6.2687 - val_reconstruction_loss: 144.3490
# Epoch 92/100
# 60000/60000 [==============================] - 9s 156us/step - loss: 144.8523 - KL_loss: 6.3469 - reconstruction_loss: 138.5054 - val_loss: 150.5604 - val_KL_loss: 6.3960 - val_reconstruction_loss: 144.1644
# Epoch 93/100
# 60000/60000 [==============================] - 10s 166us/step - loss: 144.7789 - KL_loss: 6.3393 - reconstruction_loss: 138.4396 - val_loss: 150.2738 - val_KL_loss: 6.2003 - val_reconstruction_loss: 144.0735
# Epoch 94/100
# 60000/60000 [==============================] - 9s 154us/step - loss: 144.7368 - KL_loss: 6.3457 - reconstruction_loss: 138.3911 - val_loss: 150.2970 - val_KL_loss: 6.2321 - val_reconstruction_loss: 144.0649
# Epoch 95/100
# 60000/60000 [==============================] - 9s 148us/step - loss: 144.6593 - KL_loss: 6.3497 - reconstruction_loss: 138.3095 - val_loss: 150.5902 - val_KL_loss: 6.4358 - val_reconstruction_loss: 144.1544
# Epoch 96/100
# 60000/60000 [==============================] - 9s 143us/step - loss: 144.6590 - KL_loss: 6.3651 - reconstruction_loss: 138.2938 - val_loss: 150.3552 - val_KL_loss: 6.2708 - val_reconstruction_loss: 144.0844
# Epoch 97/100
# 60000/60000 [==============================] - 10s 164us/step - loss: 144.6161 - KL_loss: 6.3586 - reconstruction_loss: 138.2575 - val_loss: 150.2692 - val_KL_loss: 6.2923 - val_reconstruction_loss: 143.9769
# Epoch 98/100
# 60000/60000 [==============================] - 10s 165us/step - loss: 144.5537 - KL_loss: 6.3611 - reconstruction_loss: 138.1926 - val_loss: 150.0711 - val_KL_loss: 6.2814 - val_reconstruction_loss: 143.7898
# Epoch 99/100
# 60000/60000 [==============================] - 10s 161us/step - loss: 144.5126 - KL_loss: 6.3589 - reconstruction_loss: 138.1536 - val_loss: 150.4528 - val_KL_loss: 6.5239 - val_reconstruction_loss: 143.9289
# Epoch 100/100
# 60000/60000 [==============================] - 10s 159us/step - loss: 144.4890 - KL_loss: 6.3734 - reconstruction_loss: 138.1156 - val_loss: 150.2972 - val_KL_loss: 6.3849 - val_reconstruction_loss: 143.9123

# %%
random_number = np.asarray([[np.random.normal() 
                            for _ in range(latent_space_depth)]])
def decode_img(a):
    a = np.clip(a * 256, 0, 255).astype('uint8')
    return PIL.Image.fromarray(a)

decode_img(decoder.predict(random_number).reshape(img_width, img_height)).resize((56, 56))
# Out:
# <PIL.Image.Image image mode=L size=56x56 at 0x128F53E80>

# %%
num_cells = 10

overview = PIL.Image.new('RGB', 
                         (num_cells * (img_width + 4) + 8, 
                          num_cells * (img_height + 4) + 8), 
                         (128, 128, 128))

vec = np.zeros((1, latent_space_depth))
for x in range(num_cells):
    vec[:, 0] = (x * 3) / (num_cells - 1) - 1.5
    for y in range(num_cells):
        vec[:, 1] = (y * 3) / (num_cells - 1) - 1.5
        decoded = decoder.predict(vec)
        img = decode_img(decoded.reshape(img_width, img_height))
        overview.paste(img, (x * (img_width + 4) + 6, y * (img_height + 4) + 6))
overview
# Out:
# <PIL.Image.Image image mode=RGB size=328x328 at 0x128F53C88>

# %%
def ConditionalVariationalAutoEncoder(num_pixels, num_labels):
    pixels = Input(shape=(num_pixels,))
    label = Input(shape=(num_labels,), name='label')

    inputs = concat([pixels, label], name='inputs')
    
    encoder_hidden = Dense(512, activation='relu', name='encoder_hidden')(inputs)

    z_mean = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    z_log_var = Dense(latent_space_depth, activation='linear')(encoder_hidden)
    
    def KL_loss(y_true, y_pred):
        return(0.5 * K.sum(K.exp(z_log_var) + K.square(z_mean) - 1 - z_log_var, axis=1))

    def reconstruction_loss(y_true, y_pred):
        return K.sum(K.binary_crossentropy(y_true, y_pred), axis=-1)    

    def total_loss(y_true, y_pred):
        return KL_loss(y_true, y_pred) + reconstruction_loss(y_true, y_pred)

    z = Lambda(sample_z, output_shape=(latent_space_depth, ))([z_mean, z_log_var])
    zc = concat([z, label])
    
    decoder_hidden = Dense(512, activation='relu')

    reconstruct_pixels = Dense(num_pixels, activation='sigmoid')

    decoder_in = Input(shape=(latent_space_depth + num_labels,))
    hidden = decoder_hidden(decoder_in)
    decoder_out = reconstruct_pixels(hidden)
    decoder = Model(decoder_in, decoder_out)    
    
    hidden = decoder_hidden(zc)
    outputs = reconstruct_pixels(hidden)
    auto_encoder = Model([pixels, label], outputs)

    auto_encoder.compile(optimizer=Adam(lr=0.001), 
                         loss=total_loss,
                         metrics=[KL_loss, reconstruction_loss])
    
    return auto_encoder, decoder

cond_auto_encoder, cond_decoder = ConditionalVariationalAutoEncoder(x_train.shape[1], y_train.shape[1])
cond_auto_encoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 784)          0
# __________________________________________________________________________________________________
# label (InputLayer)              (None, 10)           0
# __________________________________________________________________________________________________
# inputs (Concatenate)            (None, 794)          0           input_15[0][0]
#                                                                  label[0][0]
# __________________________________________________________________________________________________
# encoder_hidden (Dense)          (None, 512)          407040      inputs[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 2)            1026        encoder_hidden[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 2)            1026        encoder_hidden[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 2)            0           dense_28[0][0]
#                                                                  dense_29[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 12)           0           lambda_7[0][0]
#                                                                  label[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 512)          6656        concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 784)          402192      dense_30[1][0]
# ==================================================================================================
# Total params: 817,940
# Trainable params: 817,940
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
cond_auto_encoder.fit([x_train, y_train], x_train, verbose=1, 
                      batch_size=batch_size, epochs=50,
                      validation_data = ([x_test, y_test], x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 129.1885 - KL_loss: 4.7397 - reconstruction_loss: 124.4489 - val_loss: 130.7288 - val_KL_loss: 4.5935 - val_reconstruction_loss: 126.1352
# Epoch 2/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 129.1577 - KL_loss: 4.7555 - reconstruction_loss: 124.4022 - val_loss: 130.6913 - val_KL_loss: 4.6928 - val_reconstruction_loss: 125.9985
# Epoch 3/50
# 60000/60000 [==============================] - 6s 105us/step - loss: 129.0916 - KL_loss: 4.7557 - reconstruction_loss: 124.3359 - val_loss: 130.5601 - val_KL_loss: 4.6938 - val_reconstruction_loss: 125.8663
# Epoch 4/50
# 60000/60000 [==============================] - 6s 107us/step - loss: 129.0676 - KL_loss: 4.7525 - reconstruction_loss: 124.3151 - val_loss: 130.6311 - val_KL_loss: 4.6708 - val_reconstruction_loss: 125.9603
# Epoch 5/50
# 60000/60000 [==============================] - 7s 113us/step - loss: 129.0341 - KL_loss: 4.7648 - reconstruction_loss: 124.2693 - val_loss: 130.5953 - val_KL_loss: 4.6742 - val_reconstruction_loss: 125.9211
# Epoch 6/50
# 60000/60000 [==============================] - 7s 118us/step - loss: 128.9547 - KL_loss: 4.7700 - reconstruction_loss: 124.1846 - val_loss: 130.7554 - val_KL_loss: 4.7213 - val_reconstruction_loss: 126.0341
# Epoch 7/50
# 60000/60000 [==============================] - 7s 120us/step - loss: 128.9114 - KL_loss: 4.7632 - reconstruction_loss: 124.1482 - val_loss: 130.5908 - val_KL_loss: 4.6969 - val_reconstruction_loss: 125.8940
# Epoch 8/50
# 60000/60000 [==============================] - 7s 118us/step - loss: 128.8800 - KL_loss: 4.7775 - reconstruction_loss: 124.1026 - val_loss: 130.5680 - val_KL_loss: 4.7371 - val_reconstruction_loss: 125.8309
# Epoch 9/50
# 60000/60000 [==============================] - 7s 120us/step - loss: 128.8198 - KL_loss: 4.7759 - reconstruction_loss: 124.0438 - val_loss: 130.5840 - val_KL_loss: 4.6938 - val_reconstruction_loss: 125.8902
# Epoch 10/50
# 60000/60000 [==============================] - 7s 120us/step - loss: 128.8162 - KL_loss: 4.7827 - reconstruction_loss: 124.0335 - val_loss: 130.4100 - val_KL_loss: 4.7102 - val_reconstruction_loss: 125.6998
# Epoch 11/50
# 60000/60000 [==============================] - 7s 121us/step - loss: 128.7440 - KL_loss: 4.7807 - reconstruction_loss: 123.9633 - val_loss: 130.4184 - val_KL_loss: 4.6763 - val_reconstruction_loss: 125.7421
# Epoch 12/50
# 60000/60000 [==============================] - 7s 121us/step - loss: 128.6886 - KL_loss: 4.7810 - reconstruction_loss: 123.9076 - val_loss: 130.5873 - val_KL_loss: 4.6870 - val_reconstruction_loss: 125.9003
# Epoch 13/50
# 60000/60000 [==============================] - 7s 122us/step - loss: 128.6786 - KL_loss: 4.7939 - reconstruction_loss: 123.8848 - val_loss: 130.4877 - val_KL_loss: 4.5843 - val_reconstruction_loss: 125.9034
# Epoch 14/50
# 60000/60000 [==============================] - 8s 135us/step - loss: 128.6186 - KL_loss: 4.7930 - reconstruction_loss: 123.8256 - val_loss: 130.3514 - val_KL_loss: 4.6735 - val_reconstruction_loss: 125.6779
# Epoch 15/50
# 60000/60000 [==============================] - 9s 144us/step - loss: 128.5878 - KL_loss: 4.8020 - reconstruction_loss: 123.7858 - val_loss: 130.4407 - val_KL_loss: 4.6944 - val_reconstruction_loss: 125.7463
# Epoch 16/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 128.5360 - KL_loss: 4.8007 - reconstruction_loss: 123.7353 - val_loss: 130.5329 - val_KL_loss: 4.7235 - val_reconstruction_loss: 125.8094
# Epoch 17/50
# 60000/60000 [==============================] - 9s 143us/step - loss: 128.5092 - KL_loss: 4.8038 - reconstruction_loss: 123.7054 - val_loss: 130.4356 - val_KL_loss: 4.7344 - val_reconstruction_loss: 125.7012
# Epoch 18/50
# 60000/60000 [==============================] - 9s 143us/step - loss: 128.4706 - KL_loss: 4.8084 - reconstruction_loss: 123.6622 - val_loss: 130.4677 - val_KL_loss: 4.7195 - val_reconstruction_loss: 125.7481
# Epoch 19/50
# 60000/60000 [==============================] - 9s 143us/step - loss: 128.4370 - KL_loss: 4.8136 - reconstruction_loss: 123.6234 - val_loss: 130.4330 - val_KL_loss: 4.7023 - val_reconstruction_loss: 125.7307
# Epoch 20/50
# 60000/60000 [==============================] - 9s 142us/step - loss: 128.4062 - KL_loss: 4.8281 - reconstruction_loss: 123.5782 - val_loss: 130.3432 - val_KL_loss: 4.6758 - val_reconstruction_loss: 125.6674
# Epoch 21/50
# 60000/60000 [==============================] - 9s 148us/step - loss: 128.3523 - KL_loss: 4.8078 - reconstruction_loss: 123.5445 - val_loss: 130.4382 - val_KL_loss: 4.7706 - val_reconstruction_loss: 125.6677
# Epoch 22/50
# 60000/60000 [==============================] - 9s 156us/step - loss: 128.3244 - KL_loss: 4.8187 - reconstruction_loss: 123.5057 - val_loss: 130.4327 - val_KL_loss: 4.6568 - val_reconstruction_loss: 125.7758
# Epoch 23/50
# 60000/60000 [==============================] - 9s 151us/step - loss: 128.2972 - KL_loss: 4.8272 - reconstruction_loss: 123.4700 - val_loss: 130.4339 - val_KL_loss: 4.7960 - val_reconstruction_loss: 125.6378
# Epoch 24/50
# 60000/60000 [==============================] - 9s 147us/step - loss: 128.2462 - KL_loss: 4.8230 - reconstruction_loss: 123.4232 - val_loss: 130.3972 - val_KL_loss: 4.7540 - val_reconstruction_loss: 125.6431
# Epoch 25/50
# 60000/60000 [==============================] - 8s 131us/step - loss: 128.1760 - KL_loss: 4.8227 - reconstruction_loss: 123.3533 - val_loss: 130.4070 - val_KL_loss: 4.7383 - val_reconstruction_loss: 125.6687
# Epoch 26/50
# 60000/60000 [==============================] - 8s 130us/step - loss: 128.1845 - KL_loss: 4.8417 - reconstruction_loss: 123.3428 - val_loss: 130.3273 - val_KL_loss: 4.7022 - val_reconstruction_loss: 125.6251
# Epoch 27/50
# 60000/60000 [==============================] - 8s 134us/step - loss: 128.1547 - KL_loss: 4.8491 - reconstruction_loss: 123.3057 - val_loss: 130.3627 - val_KL_loss: 4.6926 - val_reconstruction_loss: 125.6701
# Epoch 28/50
# 60000/60000 [==============================] - 8s 130us/step - loss: 128.1241 - KL_loss: 4.8389 - reconstruction_loss: 123.2852 - val_loss: 130.3913 - val_KL_loss: 4.8135 - val_reconstruction_loss: 125.5778
# Epoch 29/50
# 60000/60000 [==============================] - 8s 134us/step - loss: 128.0994 - KL_loss: 4.8448 - reconstruction_loss: 123.2547 - val_loss: 130.3724 - val_KL_loss: 4.8552 - val_reconstruction_loss: 125.5172
# Epoch 30/50
# 60000/60000 [==============================] - 8s 129us/step - loss: 128.0658 - KL_loss: 4.8447 - reconstruction_loss: 123.2211 - val_loss: 130.2945 - val_KL_loss: 4.7329 - val_reconstruction_loss: 125.5616
# Epoch 31/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 128.0327 - KL_loss: 4.8598 - reconstruction_loss: 123.1729 - val_loss: 130.4131 - val_KL_loss: 4.8143 - val_reconstruction_loss: 125.5988
# Epoch 32/50
# 60000/60000 [==============================] - 9s 144us/step - loss: 127.9920 - KL_loss: 4.8568 - reconstruction_loss: 123.1352 - val_loss: 130.4254 - val_KL_loss: 4.7568 - val_reconstruction_loss: 125.6686
# Epoch 33/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 127.9628 - KL_loss: 4.8541 - reconstruction_loss: 123.1086 - val_loss: 130.2891 - val_KL_loss: 4.7399 - val_reconstruction_loss: 125.5492
# Epoch 34/50
# 60000/60000 [==============================] - 8s 136us/step - loss: 127.9355 - KL_loss: 4.8527 - reconstruction_loss: 123.0828 - val_loss: 130.1691 - val_KL_loss: 4.7404 - val_reconstruction_loss: 125.4286
# Epoch 35/50
# 60000/60000 [==============================] - 8s 133us/step - loss: 127.8947 - KL_loss: 4.8595 - reconstruction_loss: 123.0351 - val_loss: 130.3889 - val_KL_loss: 4.7914 - val_reconstruction_loss: 125.5976
# Epoch 36/50
# 60000/60000 [==============================] - 9s 153us/step - loss: 127.8898 - KL_loss: 4.8777 - reconstruction_loss: 123.0120 - val_loss: 130.3886 - val_KL_loss: 4.7931 - val_reconstruction_loss: 125.5955
# Epoch 37/50
# 60000/60000 [==============================] - 9s 143us/step - loss: 127.8743 - KL_loss: 4.8703 - reconstruction_loss: 123.0040 - val_loss: 130.3119 - val_KL_loss: 4.7078 - val_reconstruction_loss: 125.6041
# Epoch 38/50
# 60000/60000 [==============================] - 8s 130us/step - loss: 127.8158 - KL_loss: 4.8745 - reconstruction_loss: 122.9413 - val_loss: 130.3383 - val_KL_loss: 4.9415 - val_reconstruction_loss: 125.3968
# Epoch 39/50
# 60000/60000 [==============================] - 8s 128us/step - loss: 127.7705 - KL_loss: 4.8669 - reconstruction_loss: 122.9036 - val_loss: 130.3126 - val_KL_loss: 4.8402 - val_reconstruction_loss: 125.4724
# Epoch 40/50
# 60000/60000 [==============================] - 7s 122us/step - loss: 127.7746 - KL_loss: 4.8919 - reconstruction_loss: 122.8827 - val_loss: 130.2123 - val_KL_loss: 4.8112 - val_reconstruction_loss: 125.4010
# Epoch 41/50
# 60000/60000 [==============================] - 7s 117us/step - loss: 127.7435 - KL_loss: 4.8887 - reconstruction_loss: 122.8547 - val_loss: 130.2400 - val_KL_loss: 4.8042 - val_reconstruction_loss: 125.4357
# Epoch 42/50
# 60000/60000 [==============================] - 7s 117us/step - loss: 127.7260 - KL_loss: 4.8902 - reconstruction_loss: 122.8358 - val_loss: 130.3282 - val_KL_loss: 4.8430 - val_reconstruction_loss: 125.4852
# Epoch 43/50
# 60000/60000 [==============================] - 8s 125us/step - loss: 127.6763 - KL_loss: 4.8896 - reconstruction_loss: 122.7867 - val_loss: 130.2412 - val_KL_loss: 4.7106 - val_reconstruction_loss: 125.5306
# Epoch 44/50
# 60000/60000 [==============================] - 8s 127us/step - loss: 127.6510 - KL_loss: 4.8835 - reconstruction_loss: 122.7675 - val_loss: 130.4059 - val_KL_loss: 4.8320 - val_reconstruction_loss: 125.5739
# Epoch 45/50
# 60000/60000 [==============================] - 9s 143us/step - loss: 127.6461 - KL_loss: 4.8985 - reconstruction_loss: 122.7476 - val_loss: 130.3365 - val_KL_loss: 4.7761 - val_reconstruction_loss: 125.5604
# Epoch 46/50
# 60000/60000 [==============================] - 9s 152us/step - loss: 127.6044 - KL_loss: 4.9002 - reconstruction_loss: 122.7042 - val_loss: 130.2961 - val_KL_loss: 4.7775 - val_reconstruction_loss: 125.5186
# Epoch 47/50
# 60000/60000 [==============================] - 8s 140us/step - loss: 127.5983 - KL_loss: 4.8979 - reconstruction_loss: 122.7004 - val_loss: 130.2866 - val_KL_loss: 4.8529 - val_reconstruction_loss: 125.4337
# Epoch 48/50
# 60000/60000 [==============================] - 9s 143us/step - loss: 127.5292 - KL_loss: 4.8862 - reconstruction_loss: 122.6430 - val_loss: 130.2153 - val_KL_loss: 4.7525 - val_reconstruction_loss: 125.4628
# Epoch 49/50
# 60000/60000 [==============================] - 8s 133us/step - loss: 127.5168 - KL_loss: 4.9036 - reconstruction_loss: 122.6132 - val_loss: 130.3204 - val_KL_loss: 4.7894 - val_reconstruction_loss: 125.5310
# Epoch 50/50
# 60000/60000 [==============================] - 8s 137us/step - loss: 127.4842 - KL_loss: 4.9033 - reconstruction_loss: 122.5809 - val_loss: 130.3549 - val_KL_loss: 4.8567 - val_reconstruction_loss: 125.4981

# %%
number_4 = np.zeros((1, latent_space_depth + y_train.shape[1]))
number_4[:, 4 + latent_space_depth] = 1
decode_img(cond_decoder.predict(number_4).reshape(
               img_width, img_height)).resize((56, 56))
# Out:
# <PIL.Image.Image image mode=L size=56x56 at 0x1295D2748>

# %%
number_8_3 = np.zeros((1, latent_space_depth + y_train.shape[1]))
number_8_3[:, 8 + latent_space_depth] = 0.5
number_8_3[:, 3 + latent_space_depth] = 0.5
decode_img(cond_decoder.predict(number_8_3).reshape(
               img_width, img_height)).resize((56, 56))
# Out:
# <PIL.Image.Image image mode=L size=56x56 at 0x1295D2908>

# %%
digits = [3, 0, 8, 9]
num_cells = 10

overview = PIL.Image.new('RGB', 
                         (num_cells * (img_width + 4) + 8, 
                          num_cells * (img_height + 4) + 8), 
                         (128, 128, 128))

vec = np.zeros((1, latent_space_depth + y_train.shape[1]))
for x in range(num_cells):
    x1 = [x / (num_cells - 1), 1 - x / (num_cells - 1)]
    for y in range(num_cells):
        y1 = [y / (num_cells - 1), 1 - y / (num_cells - 1)]
        for idx, dig in enumerate(digits):
            vec[:, dig + latent_space_depth] = x1[idx % 2] * y1[idx // 2]
        decoded = cond_decoder.predict(vec)
        img = decode_img(decoded.reshape(img_width, img_height))
        overview.paste(img, (x * (img_width + 4) + 6, y * (img_height + 4) + 6))
overview
# Out:
# <PIL.Image.Image image mode=RGB size=328x328 at 0x1291F9A20>

# %%
num_cells = 10

overview = PIL.Image.new('RGB', 
                         (num_cells * (img_width + 4) + 8, 
                          num_cells * (img_height + 4) + 8), 
                         (128, 128, 128))

img_it = 0
vec = np.zeros((1, latent_space_depth + y_train.shape[1]))
for x in range(num_cells):
    vec = np.zeros((1, latent_space_depth + y_train.shape[1]))
    vec[:, x + latent_space_depth] = 1
    for y in range(num_cells):
        vec[:, 1] = 3 * y / (num_cells - 1) - 1.5
        decoded = cond_decoder.predict(vec)
        img = decode_img(decoded.reshape(img_width, img_height))
        overview.paste(img, (x * (img_width + 4) + 6, y * (img_height + 4) + 6))
overview
# Out:
# <PIL.Image.Image image mode=RGB size=328x328 at 0x129523AC8>
